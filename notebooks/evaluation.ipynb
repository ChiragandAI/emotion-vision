# %% [markdown]
# # Baseline vs Fine-Tuned Evaluation
#
# Use this notebook to compare baseline checkpoints against fine-tuned checkpoints and prepare portfolio-ready tables and figures.

# %% [markdown]
# ## Planned sections
# - load baseline and fine-tuned weights
# - compute offline metrics
# - generate confusion matrix
# - create qualitative output examples
# - summarize deployment-ready checkpoints
